# %% [markdown]
# ## Capstone Week 3

# %% [markdown]
# ## First We make the appropiate imports

# %%
import requests
import pandas as pd
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import numpy as np 

# !conda install -c anaconda beautifulsoup4 --yes 
from bs4 import BeautifulSoup
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following packages will be UPDATED:
#
#     beautifulsoup4: 4.6.0-py35h442a8c9_1 --> 4.6.3-py35_0 anaconda
#
# beautifulsoup4 100% |################################| Time: 0:00:00  38.82 MB/s

# %% [markdown]
# ## We invoke Beautiful Soup and parse the table into a Dataframe. Then we do cleanup.

# %%
wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_random_wikipedia_page=requests.get(wikipedia_link)

soup = BeautifulSoup(raw_random_wikipedia_page.content,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table), header=0)[0]

#The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood
df.rename(columns={'Postcode':'Postalcode', 'Borough':'Borough','Neighbourhood':'Neighbourhood'}, inplace=True)

#all column names to string
df.columns = list(map(str, df.columns))

#Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.
df = df[df["Borough"] != "Not assigned"]
#If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough. 
df.loc[df.Neighbourhood=="Not assigned", 'Neighbourhood'] = df["Borough"]

#More than one neighborhood can exist in one postal code area.
df = df.groupby(['Postalcode','Borough'])['Neighbourhood'].apply(lambda x: ", ".join(x.astype(str))).reset_index()
df = df.sample(frac=1).reset_index(drop=True)

df.head()
# Out:
#   Postalcode           Borough  \
# 0        M5W  Downtown Toronto
# 1        M9W         Etobicoke
# 2        M6C              York
# 3        M9R         Etobicoke
# 4        M5T  Downtown Toronto
#
#                                        Neighbourhood
# 0                    Stn A PO Boxes 25 The Esplanade
# 1                                          Northwest
# 2                                 Humewood-Cedarvale
# 3  Kingsview Village, Martin Grove Gardens, Richv...
# 4          Chinatown, Grange Park, Kensington Market

# %%
df.shape
# Out:
# (103, 5)

# %% [markdown]
# ## We call the Geo data and put it into a DF

# %%
df_geo=pd.read_csv("http://cocl.us/Geospatial_data")
df_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_final = df.set_index('Postalcode').join(df_geo.set_index('Postal Code'))
df_final = df_final.reset_index()
#df_final = df_final.sample(frac=1).reset_index(drop=True)
df_final.head(20)
# Out:
#    Postalcode           Borough  \
# 0         M5W  Downtown Toronto
# 1         M9W         Etobicoke
# 2         M6C              York
# 3         M9R         Etobicoke
# 4         M5T  Downtown Toronto
# 5         M4R   Central Toronto
# 6         M8X         Etobicoke
# 7         M4S   Central Toronto
# 8         M1K       Scarborough
# 9         M9M        North York
# 10        M6M              York
# 11        M8Z         Etobicoke
# 12        M9P         Etobicoke
# 13        M4W  Downtown Toronto
# 14        M5L  Downtown Toronto
# 15        M4J         East York
# 16        M5N   Central Toronto
# 17        M3B        North York
# 18        M6K      West Toronto
# 19        M9C         Etobicoke
#
#                                         Neighbourhood   Latitude  Longitude
# 0                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 1                                           Northwest  43.706748 -79.594054
# 2                                  Humewood-Cedarvale  43.693781 -79.428191
# 3   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 4           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 5                                  North Toronto West  43.715383 -79.405678
# 6       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 7                                          Davisville  43.704324 -79.388790
# 8         East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 9                                    Emery, Humberlea  43.724766 -79.532242
# 10     Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.691116 -79.476013
# 11  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
# 12                                          Westmount  43.696319 -79.532242
# 13                                           Rosedale  43.679563 -79.377529
# 14                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 15                                       East Toronto  43.685347 -79.338106
# 16                                           Roselawn  43.711695 -79.416936
# 17                                    Don Mills North  43.745906 -79.352188
# 18       Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 19  Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201

# %% [markdown]
# ## We need to install Folium

# %%
# !conda install -c conda-forge folium --yes
import folium
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.6.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00   2.90 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  15.84 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  36.22 MB/s
# folium-0.6.0-p 100% |################################| Time: 0:00:00  41.16 MB/s

# %% [markdown]
# ## We can now make the GeoMap

# %%
address = 'Toronto'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
map_final = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(df_final['Latitude'], df_final['Longitude'], df_final['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        ).add_to(map_final)  
    
map_final
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
